# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score
import joblib

# %% [markdown]
# ## COMMON FUNCTIONS

# %% [markdown]
# ### Data Preparation

# %%
def prepare_data(df, target_column):
    X = df.drop(columns=[target_column])
    y = df[target_column]
    return X, y

# %% [markdown]
# ### Data Splitting

# %%
def split_data(df, target, test_size=0.2, random_state=42):
    X = df.drop(columns=[target])
    y = df[target]

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    return X_train, X_test, y_train, y_test
    
df = pd.read_csv("./data/Input_data_filled_encoded.csv")
X_train, X_test, y_train, y_test = split_data(df, target="price")

# %% [markdown]
# ### Model Evaluation

# %%
# Model Evaluation for: LINEAR REGRESSION, DECISION TREE, RANDOM FOREST
def evaluate_model(model, X_test, y_test):
    predictions = model.predict(X_test)
    r2 = r2_score(y_test, predictions)
    mse = mean_squared_error(y_test, predictions)
    return {"r2": r2,"mse": mse}

# Model Evaluation for: SUPPORT VECTOR MACHINE, XGBoost
def evaluate_model_scaler(model, scaler, X_test, y_test):
    X_test_scaled = scaler.transform(X_test)  # применяем scaler
    preds = model.predict(X_test_scaled)      # предсказания
    r2 = r2_score(y_test, preds)              # метрики
    rmse = mean_squared_error(y_test, preds, squared=False)
    return {"r2": r2,"rmse": rmse}

# %% [markdown]
# ### Model Saving

# %%
def save_model(model, filename):
    joblib.dump(model, filename)

# %% [markdown]
# ### Model Loading

# %%
def load_model(filename):
    return joblib.load(filename)

# %% [markdown]
# ### Definition of Overfitting

# %%
def overfitting():
    r2_train = r2_score(y_train, model.predict(X_train_scaled))
    r2_test = r2_score(y_test, model.predict(X_test_scaled))
    print("R2 train:", r2_train," R2 test:", r2_test)
    return

# Overfitting, if: R2_train >> R2_test or RMSE_test >> RMSE_train

# %% [markdown]
# # MODEL TRAINING

# %% [markdown]
# ## LINEAR REGRESSION

# %% [markdown]
# ### Model Training + Evaluation

# %%
df = pd.read_csv("./data/Input_data_filled_encoded_std.csv")
df.head(3)
# Out:
#    postal_code     price  number_of_bedrooms  living_area  equiped_kitchen  \
# 0    -0.634228 -0.209898            0.232704    -0.446268        -0.664201
# 1    -0.857909  0.168014            0.232704     2.546700        -0.664201
# 2    -0.619316 -0.463021           -1.302127    -0.828581        -0.664201
#
#    furnished   terrace    garden  swimming_pool  \
# 0  -0.140397  0.475381 -1.084134      -0.156896
# 1  -0.140397  0.475381  0.922331      -0.156896
# 2  -0.140397  0.475381 -1.084134      -0.156896
#
#    property_type_Apartment_Apartment  ...  property_type_Apartment_Studio  \
# 0                               True  ...                           False
# 1                              False  ...                           False
# 2                               True  ...                           False
#
#    property_type_Apartment_Triplex  property_type_House_Bungalow  \
# 0                            False                         False
# 1                            False                         False
# 2                            False                         False
#
#    property_type_House_Chalet  property_type_House_Cottage  \
# 0                       False                        False
# 1                       False                        False
# 2                       False                        False
#
#    property_type_House_Mansion  property_type_House_Master house  \
# 0                        False                             False
# 1                        False                             False
# 2                        False                             False
#
#    property_type_House_Mixed building  property_type_House_Residence  \
# 0                               False                          False
# 1                               False                           True
# 2                               False                          False
#
#    property_type_House_Villa
# 0                      False
# 1                      False
# 2                      False
#
# [3 rows x 24 columns]

# %%
# Model Training
def train_linear_regression(X_train, y_train):
    model = LinearRegression()
    model.fit(X_train, y_train)
    return model
model = train_linear_regression(X_train, y_train)
# Model Evaluation
print(evaluate_model(model, X_test, y_test))
# Out:
# {'r2': 0.457072387834325, 'mse': 32264780032.228706}

# %% [markdown]
# ### Model Saving

# %%
save_model(model, "linear_model.pkl")

# %% [markdown]
# ### Model Loading

# %%
loaded_model = load_model("linear_model.pkl")

# %% [markdown]
# ## DECISION TREE

# %%
df = pd.read_csv("./data/Input_data_filled_encoded.csv")
df.head(3)
# Out:
#    postal_code   price  number_of_bedrooms  living_area  equiped_kitchen  \
# 0         2800  329000                 3.0          104                0
# 1         2200  425000                 3.0          378                0
# 2         2840  264700                 1.0           69                0
#
#    furnished  terrace  garden  swimming_pool  \
# 0          0        1       0              0
# 1          0        1       1              0
# 2          0        1       0              0
#
#    property_type_Apartment_Apartment  ...  property_type_Apartment_Studio  \
# 0                               True  ...                           False
# 1                              False  ...                           False
# 2                               True  ...                           False
#
#    property_type_Apartment_Triplex  property_type_House_Bungalow  \
# 0                            False                         False
# 1                            False                         False
# 2                            False                         False
#
#    property_type_House_Chalet  property_type_House_Cottage  \
# 0                       False                        False
# 1                       False                        False
# 2                       False                        False
#
#    property_type_House_Mansion  property_type_House_Master house  \
# 0                        False                             False
# 1                        False                             False
# 2                        False                             False
#
#    property_type_House_Mixed building  property_type_House_Residence  \
# 0                               False                          False
# 1                               False                           True
# 2                               False                          False
#
#    property_type_House_Villa
# 0                      False
# 1                      False
# 2                      False
#
# [3 rows x 24 columns]

# %% [markdown]
# ### Preparation data

# %%
X, y = prepare_data(df, "price")

# %% [markdown]
# ### Splitting Data (train/test)

# %%
def split_data(X, y, test_size=0.2, random_state=42):
    return train_test_split(X, y, test_size=test_size, random_state=random_state)

X_train, X_test, y_train, y_test = split_data(X, y)

# %% [markdown]
# ### Creating a model

# %%
def build_decision_tree_model():
    model = DecisionTreeRegressor(
        max_depth=5,            # ограничиваем глубину (борьба с переобучением)
        min_samples_split=10,   # минимальное число выборок для разбиения
        min_samples_leaf=5,     # минимальный размер листа
        random_state=42
    )
    return model
model = build_decision_tree_model()

# %% [markdown]
# ### Model Training + Evaluation

# %%
def train_model(model, X_train, y_train):
    model.fit(X_train, y_train)
    return model

model = train_model(model, X_train, y_train)
print(evaluate_model(model, X_test, y_test))
# Out:
# {'r2': 0.5229734505728445, 'mse': 28348450773.035313}

# %% [markdown]
# ### Model Saving

# %%
save_model(model, "decision_tree_model.pkl")

# %% [markdown]
# ### Model Loading

# %%
loaded_model = load_model("decision_tree_model.pkl")

# %% [markdown]
# ## RANDOM FOREST

# %%
df = pd.read_csv("./data/Input_data_filled_encoded.csv")
df.head(3)
# Out:
#    postal_code   price  number_of_bedrooms  living_area  equiped_kitchen  \
# 0         2800  329000                 3.0          104                0
# 1         2200  425000                 3.0          378                0
# 2         2840  264700                 1.0           69                0
#
#    furnished  terrace  garden  swimming_pool  \
# 0          0        1       0              0
# 1          0        1       1              0
# 2          0        1       0              0
#
#    property_type_Apartment_Apartment  ...  property_type_Apartment_Studio  \
# 0                               True  ...                           False
# 1                              False  ...                           False
# 2                               True  ...                           False
#
#    property_type_Apartment_Triplex  property_type_House_Bungalow  \
# 0                            False                         False
# 1                            False                         False
# 2                            False                         False
#
#    property_type_House_Chalet  property_type_House_Cottage  \
# 0                       False                        False
# 1                       False                        False
# 2                       False                        False
#
#    property_type_House_Mansion  property_type_House_Master house  \
# 0                        False                             False
# 1                        False                             False
# 2                        False                             False
#
#    property_type_House_Mixed building  property_type_House_Residence  \
# 0                               False                          False
# 1                               False                           True
# 2                               False                          False
#
#    property_type_House_Villa
# 0                      False
# 1                      False
# 2                      False
#
# [3 rows x 24 columns]

# %% [markdown]
# ### Model Training + Evaluation

# %%
def train_random_forest(X_train, y_train,
                        n_estimators=25, # По умолчанию - 200
                        max_depth=None,
                        random_state=42):
    model = RandomForestRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        random_state=random_state
    )
    model.fit(X_train, y_train)
    return model

model = train_random_forest(X_train, y_train)
print(evaluate_model(model, X_test, y_test))
# Out:
# {'r2': 0.6725733580549771, 'mse': 19458116224.56909}

# %% [markdown]
# ### Model Saving

# %%
save_model(model, "random_forest_model.pkl")

# %% [markdown]
# ### Model Loading

# %%
loaded_model = load_model("random_forest_model.pkl")

# %% [markdown]
# ## SUPPORT VECTOR MACHINE

# %%
df = pd.read_csv("./data/Input_data_filled_encoded_std.csv")
df.head(3)
# Out:
#    postal_code     price  number_of_bedrooms  living_area  equiped_kitchen  \
# 0    -0.634228 -0.209898            0.232704    -0.446268        -0.664201
# 1    -0.857909  0.168014            0.232704     2.546700        -0.664201
# 2    -0.619316 -0.463021           -1.302127    -0.828581        -0.664201
#
#    furnished   terrace    garden  swimming_pool  \
# 0  -0.140397  0.475381 -1.084134      -0.156896
# 1  -0.140397  0.475381  0.922331      -0.156896
# 2  -0.140397  0.475381 -1.084134      -0.156896
#
#    property_type_Apartment_Apartment  ...  property_type_Apartment_Studio  \
# 0                               True  ...                           False
# 1                              False  ...                           False
# 2                               True  ...                           False
#
#    property_type_Apartment_Triplex  property_type_House_Bungalow  \
# 0                            False                         False
# 1                            False                         False
# 2                            False                         False
#
#    property_type_House_Chalet  property_type_House_Cottage  \
# 0                       False                        False
# 1                       False                        False
# 2                       False                        False
#
#    property_type_House_Mansion  property_type_House_Master house  \
# 0                        False                             False
# 1                        False                             False
# 2                        False                             False
#
#    property_type_House_Mixed building  property_type_House_Residence  \
# 0                               False                          False
# 1                               False                           True
# 2                               False                          False
#
#    property_type_House_Villa
# 0                      False
# 1                      False
# 2                      False
#
# [3 rows x 24 columns]

# %% [markdown]
# ### Preparation data

# %%
X, y = prepare_data(df, "price")

# %% [markdown]
# ### Train/Test split

# %%
def split_data(X, y, test_size=0.2, random_state=42):
    return train_test_split(X, y, test_size=test_size, random_state=random_state)
X_train, X_test, y_train, y_test = split_data(X, y)

# %% [markdown]
# ### Creating a model

# %%
def build_svm_model():
    model = SVR(
        kernel='rbf',
        C=10,          # степень штрафа
        gamma='scale', # параметр ядра
        epsilon=0.1    # допуск отклонений
    )
    return model
model = build_svm_model()

# %% [markdown]
# ### Scaling + Training + Evaluation

# %%
from sklearn.preprocessing import StandardScaler
def train_model(model, X_train, y_train): # Масштабирует признаки и обучает SVR.Возвращает обученный scaler и модель.
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    model.fit(X_train_scaled, y_train)
    return scaler, model
scaler, model = train_model(model, X_train, y_train)

print(evaluate_model_scaler(model, scaler, X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 9
#       6     return scaler, model
#       7 scaler, model = train_model(model, X_train, y_train)
# ----> 9 print(evaluate_model_scaler(model, scaler, X_test, y_test))
#
# Cell In[9], line 13, in evaluate_model_scaler(model, scaler, X_test, y_test)
#      11 preds = model.predict(X_test_scaled)      # предсказания
#      12 r2 = r2_score(y_test, preds)              # метрики
# ---> 13 rmse = mean_squared_error(y_test, preds, squared=False)
#      14 return {"r2": r2,"rmse": rmse}
#
# File c:\Users\Becode\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py:196, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
# --> 196 params = func_sig.bind(*args, **kwargs)
#     197 params.apply_defaults()
#     199 # ignore self/cls and positional/keyword markers
#
# File c:\Users\Becode\AppData\Local\Programs\Python\Python313\Lib\inspect.py:3304, in Signature.bind(self, *args, **kwargs)
#    3299 def bind(self, /, *args, **kwargs):
#    3300     """Get a BoundArguments object, that maps the passed `args`
#    3301     and `kwargs` to the function's signature.  Raises `TypeError`
#    3302     if the passed arguments can not be bound.
#    3303     """
# -> 3304     return self._bind(args, kwargs)
#
# File c:\Users\Becode\AppData\Local\Programs\Python\Python313\Lib\inspect.py:3293, in Signature._bind(self, args, kwargs, partial)
#    3283         raise TypeError(
#    3284             'got some positional-only arguments passed as '
#    3285             'keyword arguments: {arg!r}'.format(
#    (...)   3290             ),
#    3291         )
#    3292     else:
# -> 3293         raise TypeError(
#    3294             'got an unexpected keyword argument {arg!r}'.format(
#    3295                 arg=next(iter(kwargs))))
#    3297 return self._bound_arguments_cls(self, arguments)
#
# TypeError: got an unexpected keyword argument 'squared'

# %% [markdown]
# ### Model Saving

# %%
def save_model_SVM(model, scaler, filepath="svm_regressor.pkl"):
    joblib.dump({"model": model, "scaler": scaler}, filepath)
    return
save_model_SVM(model, scaler)

# %% [markdown]
# ### Model Loading

# %%
def load_model(filepath="svm_regressor.pkl"):
    saved = joblib.load(filepath)
    return saved["model"], saved["scaler"]

# %% [markdown]
# ## XGBoost MODEL

# %%
df = pd.read_csv("./data/Input_data_filled.csv")
df.head(3)
# Out:
#    postal_code   price  number_of_bedrooms  living_area  equiped_kitchen  \
# 0         2800  329000                 3.0          104                0
# 1         2200  425000                 3.0          378                0
# 2         2840  264700                 1.0           69                0
#
#    furnished  terrace  garden  swimming_pool        property_type
# 0          0        1       0              0  Apartment_Apartment
# 1          0        1       1              0      House_Residence
# 2          0        1       0              0  Apartment_Apartment

# %% [markdown]
# ### Model Building + Training + Evaluation

# %%
def build_xgb_model():
    model = XGBRegressor(
    n_estimators=775, # Количество деревьев в ансамбле, чем больше, тем выше качество, но медленнее обучение, типовое значение: 100–1000
    learning_rate=0.0125, # Скорость обучения, Маленькое значение = модель учится медленно, но устойчиво, большое значение = модель быстрее переобучается, Обычно 0.01–0.3
    max_depth=6, # Максимальная глубина каждого дерева, глубокие деревья → модель точнее, но легко переобучается, Мелкие деревья → более обобщающие. Типичный диапазон: 3–10
    subsample=0.8, # Доля строк (обучающих наблюдений), используемая для каждого дерева. 0.8 = каждое дерево обучается на 80% случайно выбранных данных. Помогает бороться с переобучением
    colsample_bytree=0.78, # Доля признаков (features), используемых для построения каждого дерева. 0.8 = использовать 80% случайных колонок на дерево. Помогает снизить переобучение и ускорить обучение
    objective="reg:squarederror",
    random_state=42 # Фиксация случайности. Нужна, чтобы модель каждый раз давала одинаковый результат при одних и тех же данных
    )
    return model

def train_model(model, X_train, y_train):
    model.fit(X_train, y_train)
    return model

model = build_xgb_model()
model = train_model(model, X_train, y_train)
print(evaluate_model(model, X_test, y_test))
# Out:
# {'r2': 0.7048772316545796, 'mse': 0.271787180919992}

# %% [markdown]
# ### Model Saving

# %%
save_model(model, "price_xgb.pkl")

# %% [markdown]
# ### Model Loading

# %%
loaded_model = load_model("price_xgb.pkl")
